# %%
import pandas as pd
from git import db

#构建DateFrame,表格
df=pd.DataFrame ([{
        "姓名":"llh","性别":"男","age":17
    },
        {
        "姓名":"mys","性别":"女","age":19
    }
    ]
)
f"年龄最大:{df['age'].max()}"
# Out:
# '年龄最大:19'
