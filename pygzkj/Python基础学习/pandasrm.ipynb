# %%
import pandas as pd

pf = pd.read_csv('mokuai/第二次抓取电影网站数据.csv',usecols=["电影名称","年份","上映时间","类型"])
pf
# Out:
#                      电影名称      年份             上映时间              类型
# 0              安昂传奇：最后的气宗  (2026)  2026-07-24 (US)     动画，动作，冒险，奇幻
# 1                 不期而遇的姐妹  (2026)  2026-03-12 (MX)           喜剧，爱情
# 2                 奇幻变身大冒险  (2026)  2026-05-01 (US)     冒险，动画，家庭，奇幻
# 3                  肖申克的救赎  (1994)  1994-09-23 (US)           剧情，犯罪
# 4            迈克尔·杰克逊：巨星之路  (2026)  2026-04-24 (CN)           音乐，剧情
# ..                    ...     ...              ...             ...
# 95                  现代启示录  (1979)  1979-05-19 (CN)           剧情，战争
# 96                   萤火之森  (2011)  2011-09-17 (JP)        爱情，动画，奇幻
# 97             迈克尔·杰克逊：颤栗  (1983)  1983-11-21 (US)        恐怖，音乐，惊悚
# 98  新世纪福音战士剧场版：Air / 真心为你  (1997)  1997-07-19 (JP)  动画，科幻，剧情，奇幻，动作
# 99                     痴迷  (2026)  2026-07-24 (CN)           恐怖，惊悚
#
# [100 rows x 4 columns]
